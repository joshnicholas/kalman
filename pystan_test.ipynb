# %%
# !pip install pystan
# !pip install pystan
# !python3 -m pip install pystan
import stan
# Out:
# Running cells with 'envy (Python 3.12.2)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/josh_nicholas/envy/bin/activate -m pip install ipykernel -U --force-reinstall'

# %%
### Example from here: https://pystan.readthedocs.io/en/latest/

schools_code = """
data {
  int<lower=0> J;         // number of schools
  array[J] real y;              // estimated treatment effects
  array[J] real<lower=0> sigma; // standard error of effect estimates
}
parameters {
  real mu;                // population treatment effect
  real<lower=0> tau;      // standard deviation in treatment effects
  vector[J] eta;          // unscaled deviation from mu by school
}
transformed parameters {
  vector[J] theta = mu + tau * eta;        // school treatment effects
}
model {
  target += normal_lpdf(eta | 0, 1);       // prior log-density
  target += normal_lpdf(y | theta, sigma); // log-likelihood
}
"""

schools_data = {"J": 8,
                "y": [28,  8, -3,  7, -1,  1, 18, 12],
                "sigma": [15, 10, 16, 11,  9, 11, 10, 18]}

posterior = pystan.build(schools_code, data=schools_data, random_seed=1)
fit = posterior.sample(num_chains=4, num_samples=1000)
eta = fit["eta"]  # array with shape (8, 4000)
df = fit.to_frame()  # pandas `DataFrame, requires pandas

print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 27
#       3 schools_code = """
#       4 data {
#       5   int<lower=0> J;         // number of schools
#    (...)
#      20 }
#      21 """
#      23 schools_data = {"J": 8,
#      24                 "y": [28,  8, -3,  7, -1,  1, 18, 12],
#      25                 "sigma": [15, 10, 16, 11,  9, 11, 10, 18]}
# ---> 27 posterior = pystan.build(schools_code, data=schools_data, random_seed=1)
#      28 fit = posterior.sample(num_chains=4, num_samples=1000)
#      29 eta = fit["eta"]  # array with shape (8, 4000)
#
# AttributeError: module 'pystan' has no attribute 'build'
